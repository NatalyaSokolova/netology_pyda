# %% [markdown]
# ## Задание 1

# %% [markdown]
# Скачайте с сайта https://grouplens.org/datasets/movielens/ датасет любого размера. Определите какому фильму было выставлено больше всего оценок 5.0.

# %%
import pandas as pd
ratings=pd.read_csv(r'C:\Users\Natasha\Downloads\ml-latest-small\ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
df1 = ratings[ ratings.rating == 5 ].groupby('movieId').count().sort_values('rating', ascending=False).head().reset_index()
print(df1)

bestmovie = df1['movieId'][0]
bestmovie
# Out:
#    movieId  userId  rating  timestamp
# 0      318     153     153        153
# 1      296     123     123        123
# 2      356     116     116        116
# 3     2571     109     109        109
# 4      260     104     104        104
# 318

# %%
#Импортируем файл с наименованиями фильмов
movies_names=pd.read_csv(r'C:\Users\Natasha\Downloads\ml-latest-small\movies.csv')
movies_names.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
d = movies_names[movies_names.movieId == bestmovie].head(10)
d
# Out:
#      movieId                             title       genres
# 277      318  Shawshank Redemption, The (1994)  Crime|Drama

# %% [markdown]
# ## Задание 2

# %% [markdown]
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
#Решение 1
import pandas as pd
data=pd.read_csv(r'C:\Users\Natasha\Downloads\ml-latest-small\power.csv')
data.head()
# Out:
#    country  year  quantity  category
# 0  Austria  1996       5.0         1
# 1  Austria  1995      17.0         1
# 2  Belgium  2014       0.0         1
# 3  Belgium  2013       0.0         1
# 4  Belgium  2012      35.0         1

# %%
#Фильтр по стране
filtered_countries = data[ (data['country']=='Latvia') | (data['country']=='Lithuania') | (data['country']=='Estonia') ]
#Фильтр по №№ категории
filtered_categories = filtered_countries[(filtered_countries.category == 4)|(filtered_countries.category == 12)|(filtered_countries.category == 21)]
#Фильтр по году
filtered_period = filtered_categories[(filtered_categories.year >= 2005)&(filtered_categories.year <= 2010)]
#Фильтр по неотриц.количеству
filtered_end = filtered_period[filtered_period.quantity >= 0]
filtered_end['quantity'].sum()
# Out:
# 240580.0

# %%
#Решение 2
#Непонятно почему разные результаты с вариантом решения №1 :'(
#И непонятно как остановить подсчет списка, пробовала pass и end, результат отрицательный :(

import pandas as pd
df=pd.read_csv(r'C:\Users\Natasha\Downloads\ml-latest-small\power.csv')
df.head()

#2. Получаем названия стран 
df['country'].unique()

#3.Выставляем фильтры
for df['category'] in [4,12,21]:
    for df['country'] in ['Lithuania', 'Latvia','Estonia']:
        for x in df['quantity'] > 0:
            for df['year'] in range(2005,2010):
                consumption=df['quantity'].sum()
                print(consumption)
                pass
# Out:
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# 219179627208.76712
# ...

# %% [markdown]
# ## Задание 3

# %% [markdown]
# Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.
# Примеры страниц (необязательно брать именно эти):
# https://fortrader.org/quotes
# https://www.finanz.ru/valyuty/v-realnom-vremeni

# %%
df1 = pd.read_html(
    'https://www.oilworld.ru/analytics/databases/fortotal', encoding='utf-8')[0]

df1.head(10)
# Out:
#               Наименование     Страна          Базис Дата торгов  \
# 0          Кокосовое масло  Индонезия  FOB Indonesia  30.09.2019
# 1          Кокосовое масло  Индонезия  FOB Indonesia  31.10.2019
# 2          Кокосовое масло  Индонезия  FOB Indonesia  29.11.2019
# 3          Кокосовое масло  Индонезия  FOB Indonesia  31.12.2019
# 4          Кокосовое масло  Индонезия  FOB Indonesia  29.01.2020
# 5  Пальмоядровое масло РБД   Малайзия   FOB Malaysia  31.12.2019
# 6  Пальмоядровое масло РБД   Малайзия   FOB Malaysia  29.01.2020
# 7      Пальмовое масло РБД   Малайзия   FOB Malaysia  31.12.2019
# 8      Пальмовое масло РБД   Малайзия   FOB Malaysia  29.01.2020
# 9      Пальмовое масло РБД   Малайзия   FOB Malaysia  29.01.2020
#
#       Торги на: Ед. изм.     Цена  За нед. За мес.     Мин.    Макс.  Граф.  \
# 0   Январь 2020    USD/T   781.54    -9.92       —   772.72   839.96    NaN
# 1  Февраль 2020    USD/T   805.79    19.84       —   781.54   838.86    NaN
# ...

# %%
df2 = pd.read_html(
    'https://www.oilworld.ru/', encoding='utf-8')[1]
df2
# Out:
#   Регион   Закуп.    Изм.    Прод.  Изм..1
# 0    ЦФО  45500.0  + 1000  46933.0  + 1233
# 1    ПФО  45100.0  + 1700  45200.0  + 1100
# 2    ЮФО  46700.0  + 1900  49225.0  + 3425
# 3    СФО  44400.0   + 400  44800.0   - 700
